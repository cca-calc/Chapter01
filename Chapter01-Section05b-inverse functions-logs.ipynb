# %% [markdown]
# ### Chapter 1, Section 5: This lesson deals with exponential inverse functions.
# - Problems: Paper (27, 32, 39, 42, 43, 45, 59).
# - Problems: Jupyter 27, 32  are done below.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the domain for each function
x_exp = np.linspace(0.0, 3, 100)   
y_exp = np.exp(1- x_exp) 

x_inv = np.linspace(np.e, 3-np.e, 100) 
y_inv = 1 - np.log(x_inv)  

# Plotting
plt.plot(x_exp, y_exp, label="$f(x) = e[1-x]$", color='blue')
plt.plot(x_inv, y_inv, label="$f(x) = 1 - ln(x)", color='green')
plt.plot(x_exp, x_exp, label="y = x (line of symmetry)", linestyle='--', color='gray')

plt.title("Exponential Function and Its Inverse")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.axis('equal') 
plt.show()

# %%
# Define the domain for each function
x_exp = np.linspace(-1, 1, 100)   
y_exp = 1 + np.exp(-x_exp) 

x_inv = np.linspace(1 + np.e, 1+np.e**(-1), 100) 
y_inv =- np.log(x_inv -1)  

x_sym = np.linspace(0, 4, 100)
# Plotting
plt.plot(x_exp, y_exp, label="$f(x) = 1 + e[-x]$", color='blue')
plt.plot(x_inv, y_inv, label="$f(x) = - ln(x -1)", color='green')
plt.plot(x_sym, x_sym, label="y = x (line of symmetry)", linestyle='--', color='gray')

plt.title("Exponential Function and Its Inverse")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.axis('equal') 
plt.show()
